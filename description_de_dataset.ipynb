# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/Ter_ATAL/Dataset_TER/dataset.csv',sep = '\t')
data.head()
# Out:
#                  document                                            content  \
# 0  ROSENBLATT v. BAER_MCL  MR. JUSTICE BRENNAN delivered the opinion of t...
# 1  ROSENBLATT v. BAER_MCL  A jury in New Hampshire Superior Court awarded...
# 2  ROSENBLATT v. BAER_MCL  Respondent alleged that the column contained d...
# 3  ROSENBLATT v. BAER_MCL  In the interval between the trial and the deci...
# 4  ROSENBLATT v. BAER_MCL  We there held that consistent with the First a...
#
#                                 tag
# 0               Announcing function
# 1  Describing the adjudicated facts
# 2      Describing procedural events
# 3  Describing the adjudicated facts
# 4       Recalling a SCOTUS decision

# %%
data.describe()
# Out:
#                                               document content  \
# count                                             2397    2397
# unique                                              18    2352
# top     opinion-G16-(Taylor v. Sturgell, 553 U.S. 880)   Ibid.
# freq                                               365      12
#
#                                                       tag
# count                                                2397
# unique                                                 38
# top     Citing primary sources (other than SCOTUS deci...
# freq                                                  258

# %%
data.isnull().sum()
# Out:
# document    0
# content     0
# tag         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2397 entries, 0 to 2396
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   document  2397 non-null   object
#  1   content   2397 non-null   object
#  2   tag       2397 non-null   object
# dtypes: object(3)
# memory usage: 56.3+ KB
